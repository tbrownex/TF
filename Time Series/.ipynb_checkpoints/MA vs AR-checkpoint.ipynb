# %%
import numpy as np

# %%
errors = np.random.normal(size=100)
init = 1.0
Beta = .7
Theta = .5

# %%
ARmodel = [init]
for x in range(1,100):
    tmp = ARmodel[x-1]*Beta+errors[x]
    ARmodel.append(tmp)
# Out:
# 1.0 0.7 -1.1032615833091466
# -0.40326158330914663 0.7 -1.4823770221147707
# -1.7646601304311733 0.7 -0.6204872993584212
# -1.8557493906602425 0.7 1.1929597010766544
# -0.10606487238551532 0.7 2.0135818440112523
# 1.9393364333413916 0.7 0.31285087373107107
# 1.6703863770700451 0.7 -0.8556482538206793
# 0.3136222101283521 0.7 -1.2146025004575818
# -0.9950669533677353 0.7 1.4530255657973161
# 0.7564786984399015 0.7 0.45553128512541174
# 0.9850663740333427 0.7 1.4253771712424772
# 2.114923633065817 0.7 -0.340090377713364
# 1.1403561654327081 0.7 -0.5594364120490048
# 0.23881290375389075 0.7 -1.150938929167617
# -0.9837698965398936 0.7 0.03094270573656364
# -0.6576962218413618 0.7 0.26721498329273385
# -0.19317237199621934 0.7 -0.6347389193675783
# -0.7699595797649319 0.7 0.45855015251636677
# -0.08042155331908551 0.7 0.7659642848484876
# 0.7096691975251277 0.7 0.24097409759636365
# 0.737742535863953 0.7 0.07564259628026178
# 0.5920623713850289 0.7 -0.2958254193445958
# ...

# %%
errors[:2]
# Out:
# array([-0.02256447, -1.10326158])

# %%
ARmodel
# Out:
# [1.0,
#  -0.40326158330914663,
#  -1.7646601304311733,
#  -1.8557493906602425,
#  -0.10606487238551532,
#  1.9393364333413916,
#  1.6703863770700451,
#  0.3136222101283521,
#  -0.9950669533677353,
#  0.7564786984399015,
#  0.9850663740333427,
#  2.114923633065817,
#  1.1403561654327081,
#  0.23881290375389075,
#  -0.9837698965398936,
#  -0.6576962218413618,
#  -0.19317237199621934,
#  -0.7699595797649319,
#  -0.08042155331908551,
#  0.7096691975251277,
#  0.737742535863953,
#  0.5920623713850289,
#  0.11861824062492443,
#  0.8515734999224727,
#  0.24213024252536042,
#  -0.7918562202276244,
#  1.05354168968388,
#  1.396365527715021,
#  0.2966124508538329,
#  0.564545838387162,
#  1.0642651527165257,
#  1.5029371516501469,
#  1.9637189688897028,
#  0.43154570616756593,
#  2.9754493134741837,
#  1.775971770148383,
#  1.2506336369938824,
#  0.6639631750433787,
#  0.9863505791168178,
#  0.15492493204072355,
#  1.3312429543699174,
#  0.36103112080315647,
#  0.4674899631024145,
# ...
